# %%
import pandas as pd

# %%
df = pd.read_csv('players.csv')

# %%
df
# Out:
#              full_school_name     school_name      player_name position  \
# 0         Cincinnati Bearcats      Cincinnati  Ralph Abernathy       RB
# 1         Cincinnati Bearcats      Cincinnati     Mekale McKay       WR
# 2         Cincinnati Bearcats      Cincinnati      Trenier Orr       CB
# 3         Cincinnati Bearcats      Cincinnati     Bennie Coney       QB
# 4         Cincinnati Bearcats      Cincinnati    Johnny Holton       WR
# ...                       ...             ...              ...      ...
# 9995  San Jose State Spartans  San Jose State    Nate Velichko       OT
# 9996  San Jose State Spartans  San Jose State      Evan Sarver       OT
# 9997  San Jose State Spartans  San Jose State     Oscar Barron        G
# 9998  San Jose State Spartans  San Jose State        Jon Meyer       OT
# 9999  San Jose State Spartans  San Jose State       Max Miller       TE
#
#       height  weight year           hometown state     id
# ...

# %%
df['state'].unique
# Out:
# <bound method Series.unique of 0       GA
# 1       KY
# 2       FL
# 3       FL
# 4       FL
#         ..
# 9995    CA
# 9996    AZ
# 9997    CA
# 9998    CA
# 9999    IA
# Name: state, Length: 10000, dtype: object>
